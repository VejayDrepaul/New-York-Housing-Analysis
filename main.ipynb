# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

plt.style.use("dark_background")
#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
pd.reset_option('max_columns')

# %% [markdown]
# ### Preparing Data for Analysis

# %%
df = pd.read_csv("ny_housing_data.csv")
df
# Out:
#                                             BROKERTITLE                TYPE  \
# 0           Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                   Brokered by Serhant      Condo for sale
# 2                                Brokered by Sowae Corp      House for sale
# 3                                   Brokered by COMPASS      Condo for sale
# 4     Brokered by Sotheby's International Realty - E...  Townhouse for sale
# ...                                                 ...                 ...
# 4796                                Brokered by COMPASS      Co-op for sale
# 4797                    Brokered by Mjr Real Estate Llc      Co-op for sale
# 4798      Brokered by Douglas Elliman - 575 Madison Ave      Co-op for sale
# 4799            Brokered by E Realty International Corp      Condo for sale
# 4800                 Brokered by Nyc Realty Brokers Llc      Co-op for sale
#
#           PRICE  BEDS       BATH  PROPERTYSQFT  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4801 entries, 0 to 4800
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   BROKERTITLE                  4801 non-null   object
#  1   TYPE                         4801 non-null   object
#  2   PRICE                        4801 non-null   int64
#  3   BEDS                         4801 non-null   int64
#  4   BATH                         4801 non-null   float64
#  5   PROPERTYSQFT                 4801 non-null   float64
#  6   ADDRESS                      4801 non-null   object
#  7   STATE                        4801 non-null   object
#  8   MAIN_ADDRESS                 4801 non-null   object
#  9   ADMINISTRATIVE_AREA_LEVEL_2  4801 non-null   object
#  10  LOCALITY                     4801 non-null   object
#  11  SUBLOCALITY                  4801 non-null   object
#  12  STREET_NAME                  4801 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# BROKERTITLE                    0
# TYPE                           0
# PRICE                          0
# BEDS                           0
# BATH                           0
# PROPERTYSQFT                   0
# ADDRESS                        0
# STATE                          0
# MAIN_ADDRESS                   0
# ADMINISTRATIVE_AREA_LEVEL_2    0
# LOCALITY                       0
# SUBLOCALITY                    0
# STREET_NAME                    0
# LONG_NAME                      0
# FORMATTED_ADDRESS              0
# LATITUDE                       0
# LONGITUDE                      0
# dtype: int64

# %%
df.describe()
# Out:
#               PRICE         BEDS         BATH  PROPERTYSQFT     LATITUDE  \
# count  4.801000e+03  4801.000000  4801.000000   4801.000000  4801.000000
# mean   2.356940e+06     3.356801     2.373861   2184.207862    40.714227
# std    3.135525e+07     2.602315     1.946962   2377.140894     0.087676
# min    2.494000e+03     1.000000     0.000000    230.000000    40.499546
# 25%    4.990000e+05     2.000000     1.000000   1200.000000    40.639375
# 50%    8.250000e+05     3.000000     2.000000   2184.207862    40.726749
# 75%    1.495000e+06     4.000000     3.000000   2184.207862    40.771923
# max    2.147484e+09    50.000000    50.000000  65535.000000    40.912729
#
#          LONGITUDE
# count  4801.000000
# mean    -73.941601
# std       0.101082
# min     -74.253033
# 25%     -73.987143
# 50%     -73.949189
# 75%     -73.870638
# max     -73.702450

# %%
df = df.drop(columns=["LATITUDE", "LONGITUDE"])
df = df.rename(columns={"PROPERTYSQFT": "PROPERTY_SQFT"})
df
# Out:
#                                             BROKERTITLE                TYPE  \
# 0           Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                   Brokered by Serhant      Condo for sale
# 2                                Brokered by Sowae Corp      House for sale
# 3                                   Brokered by COMPASS      Condo for sale
# 4     Brokered by Sotheby's International Realty - E...  Townhouse for sale
# ...                                                 ...                 ...
# 4796                                Brokered by COMPASS      Co-op for sale
# 4797                    Brokered by Mjr Real Estate Llc      Co-op for sale
# 4798      Brokered by Douglas Elliman - 575 Madison Ave      Co-op for sale
# 4799            Brokered by E Realty International Corp      Condo for sale
# 4800                 Brokered by Nyc Realty Brokers Llc      Co-op for sale
#
#           PRICE  BEDS       BATH  PROPERTY_SQFT  \
# ...

# %% [markdown]
# ### Biggest Brokers Analysis

# %%
broker_data = df["BROKERTITLE"].value_counts().to_frame().reset_index()
broker_data.rename(columns={"count": "PROPERTY_COUNT"}, inplace=True)

broker_data.head(10) # shows biggest 10 brokers in NY
# Out:
#                                          BROKERTITLE  PROPERTY_COUNT
# 0                                Brokered by COMPASS             456
# 1      Brokered by Douglas Elliman - 575 Madison Ave             110
# 2                   Brokered by Brown Harris Stevens              93
# 3                     Brokered by Corcoran East Side              91
# 4                            Brokered by RE MAX Edge              79
# 5                     Brokered by Winzone Realty Inc              68
# 6  Brokered by Sotheby's International Realty - E...              62
# 7            Brokered by E Realty International Corp              59
# 8                                Brokered by Serhant              54
# 9       Brokered by RE MAX Real Estate Professionals              52

# %% [markdown]
# ### Corellation Between Squarefootage and Price

# %%
house_characteristics = df[["PROPERTY_SQFT", "PRICE", "BEDS", "BATH"]]
house_characteristics = house_characteristics.sort_values(by="PRICE", ascending=False).reset_index()
house_characteristics = house_characteristics.drop(columns={"index"})
house_characteristics
# Out:
#       PROPERTY_SQFT       PRICE  BEDS       BATH
# 0      10000.000000  2147483647     7   6.000000
# 1      17545.000000   195000000     7  10.000000
# 2      15200.000000    65000000     3   2.373861
# 3       2184.207862    60000000     8   8.000000
# 4      24000.000000    56000000    11  10.000000
# ...             ...         ...   ...        ...
# 4796     445.000000       60000     3   1.000000
# 4797     800.000000       49500     3   2.373861
# 4798    2184.207862        5800     3   2.373861
# 4799    2184.207862        3225     3   1.000000
# 4800    2184.207862        2494     2   1.000000
#
# [4801 rows x 4 columns]

# %%
house_characteristics.mean()
# Out:
# PROPERTY_SQFT    2.184208e+03
# PRICE            2.356940e+06
# BEDS             3.356801e+00
# BATH             2.373861e+00
# dtype: float64

# %%
reg_x = house_characteristics[["PROPERTY_SQFT"]]
reg_y = house_characteristics["PRICE"]
X_train, X_test, y_train, y_test = train_test_split(reg_x, reg_y, test_size=0.2, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

sns.scatterplot(data=house_characteristics, x="PROPERTY_SQFT", y="PRICE", label="House Prices", legend='auto')
sns.lineplot(x=X_test.squeeze(), y=y_pred, color='blue', linewidth=3, label='Predicted', legend='auto')
plt.ylabel("Price ($)")
plt.xlabel("Property Square Footage")
plt.title('Linear Regression Model with Seaborn')
plt.legend()

plt.show()

# %% [markdown]
# ### Areas With Most Properties in New York

# %%
big_areas = df["STREET_NAME"].value_counts().to_frame().reset_index()
big_areas = big_areas.rename(columns={"count": "#_OF_PROPERTIES"})
big_areas = big_areas.sort_values(by="#_OF_PROPERTIES", ascending=False)
big_seven = big_areas.head(7)

ax = sns.barplot(data=big_seven, x="STREET_NAME", y="#_OF_PROPERTIES", width=0.8)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
plt.title("Areas With the Most Properties")
plt.xlabel("Areas of New York")
plt.ylabel("# of Properties")
# Out:
# Text(0, 0.5, '# of Properties')

# %% [markdown]
# ### Most Expensive Housing in New York

# %%
housing_prices = df[["PRICE", "STREET_NAME"]]

for x in big_areas.index:
    if big_areas["#_OF_PROPERTIES"][x] > 10:
        big_areas.drop(x, inplace=True)


housing_prices["BOOLEAN"] = housing_prices["STREET_NAME"].isin(big_areas["STREET_NAME"])

for x in housing_prices.index:
    if housing_prices["BOOLEAN"][x] == True:
        housing_prices.drop(x, inplace=True)

avg_house_price = housing_prices.groupby("STREET_NAME")["PRICE"].mean().reset_index()
avg_house_price.sort_values(by="PRICE", ascending=False, inplace=True)
highest_prices = avg_house_price[:7]

fig = px.bar(data_frame=highest_prices, x="STREET_NAME", y="PRICE")
fig.show()
# Out:
# C:\Users\drepa\AppData\Local\Temp\ipykernel_1888\2972421586.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\drepa\AppData\Local\Temp\ipykernel_1888\2972421586.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\drepa\AppData\Local\Temp\ipykernel_1888\2972421586.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %% [markdown]
# ### Bed and Bathroom Trends
